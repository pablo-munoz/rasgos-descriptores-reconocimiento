# %% [markdown]
# # Segmentation

# %% [markdown]
# The purpose of segmentation is to separate the background from the objects of interest. Segmentation becomes significantly harder when objects are overlapped.

# %%
# Imports
import scipy.misc
import numpy as np
import numpy.ma
from matplotlib import pyplot as plt
from functools import partial

# %%
# Manifest Constants
IMAGE_PATH = '../images/key.jpg'

# %%
color_image_data = scipy.misc.imread(IMAGE_PATH)
gray_image_data = scipy.misc.imread(IMAGE_PATH, mode='L')

# %%
plt.imshow(color_image_data)

# %%
plt.imshow(gray_image_data, cmap='gray')

# %% [markdown]
# One of the approaches in the book is to "binarize" the images given some threshold.

# %%
def binarize(image_data, threshold, low=0, high=255):
    '''
    Returns the binarization of an ndarray containing an
    image's pixel intensities, i.e. returns an ndarray of
    the same dimensions as IMAGE_DATA, where all the element
    values are either LOW or HIGH, depending on whether the
    corresponding element in the origial IMAGE_DATA is lower
    than, or greater than the given THRESHOLD.
    
    >>>data = np.array([243, 3],
                        [245, 2])
    >>>binarize(dadta, threshold=200)
    array([255, 0],
            [255, 0])
    '''
    return np.vectorize(lambda el: high if el > threshold else low)(image_data)

# %% [markdown]
# Now the issue becomes about how to determine the threshold.

# %% [markdown]
# ## Automatic thresholding

# %% [markdown]
# ### Method based on the mode
#
# With this method we work under the assumption that if we plot the histogram of the pixel intensities of an image's data, we will see two modes. One for the most common intensity value for the background, and the other for the most common value of the objects in the foreground.

# %%
n, bins, patches = plt.hist(gray_image_data.ravel(), bins=255, normed=True)

# %%
threshold = 120
result = binarize(gray_image_data, threshold)
plt.imshow(result, cmap='gray')

# %% [markdown]
# ### Iterative method
#
# 1. Select an initial threshold. The average is a good candiate.
# 2. Segment the image in two sections based on the threshold.
# 3. Calculate the mean values of each of the segmented regions.
# 4. Improve the threshold to be the average of the two new thresholds.
# 5. Repeat steps two to four untill convergence.

# %%
def iterative_threshold(image_data, convergence_delta=1):
    '''
    Return a threshold for image binarization. The
    threshold is calculated using the iterative
    method:
    
    1. Select an initial threshold. The average is good.
    2. Segment the image in two sections based on the threshold.
    3. Calculate the mean values of each of the segmented regions.
    4. Improve the threshold to be the average of the two new thresholds.
    5. Repeat steps two to four untill convergence.
    '''
    old_threshold = None
    threshold = image_data.mean()
    num_pixels = len(image_data.ravel())
    delta = 65536 # Impossibly high value
    while delta > convergence_delta:
        binarization = binarize(image_data, threshold=threshold, low=False, high=True)
        # Use the binarization as a mask to isolate the pixel values that
        # ended up in each of the segments
        segment_1 = np.trim_zeros(np.ma.array(image_data, mask=binarization).ravel())
        segment_1_mean = segment_1.mean()
        # Negate the binarization to use as a mask for the other segment
        not_binarization = np.vectorize(lambda x: not x)(binarization)
        segment_2 = np.trim_zeros(np.ma.array(image_data, mask=not_binarization).ravel())
        segment_2_mean = segment_2.mean()
        old_threshold = threshold
        threshold = np.mean((segment_1_mean, segment_2_mean))
        delta = abs(threshold - old_threshold)
    return threshold


threshold = iterative_threshold(gray_image_data)
result = binarize(gray_image_data, threshold=threshold)

plt.figure()
plt.title('Threshold = {:4.2f} (by iteration)'.format(threshold))
plt.imshow(result, cmap='gray')

# %% [markdown]
# ### Adaptive method
#
# For the adaptive method, the image is broken up (often into equal sized pieces) and each piece is segmentated with a method. Then the whole image is put together.

# %%
def break_image_into_pieces(image_data, piece_dimension):
    '''
    Given an IMAGE_DATA ndarray (asummed to be bidimensional)
    break it into a list of smaller ndarrays such that
    there are NUM_ROWS * NUM_COLS pieces and that all
    the pieces together form a non overlapping partition
    of IMAGE_DATA.
    '''
    shape = image_data.shape
    image_rows = shape[0]
    image_cols = shape[1]
    piece_rows = piece_dimension[0]
    piece_cols = piece_dimension[1]
    pieces = []
    for i in range(piece_rows):
        for j in range(piece_cols):
            piece_row_range = [i * piece_rows, (i+1) * piece_rows]
            piece_col_range = [j * piece_cols, (j+1) * piece_cols]
            pieces.append(image_data[piece_row_range, piece_col_range].copy())
    
    return pieces

break_image_into_pieces(gray_image_data, piece_dimension=(200, 200))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-16bb560cf536> in <module>()
#      21     return pieces
#      22
# ---> 23 break_image_into_pieces(gray_image_data, piece_dimension=(200, 200))
#
# <ipython-input-62-16bb560cf536> in break_image_into_pieces(image_data, piece_dimension)
#      17             piece_row_range = [i * piece_rows, (i+1) * piece_rows]
#      18             piece_col_range = [j * piece_cols, (j+1) * piece_cols]
# ---> 19             pieces.append(image_data[piece_row_range, piece_col_range].copy())
#      20
#      21     return pieces
#
# IndexError: index 1200 is out of bounds for axis 1 with size 1200

# %%
def segment_image_piece(piece):
    threshold = iterative_method(piece)
    binarize_piece = np.vectorize(partial(binarize_image, threshold=threshold))
    return binarize_piece(piece)
    

image_pieces_segmented = list(map(segment_image_piece, additive_method_image_pieces))

# %%
# slice to only show a few
for piece in image_pieces_segmented[0:-1:4]:
    plt.figure()
    show_image_grayscale(piece)

# %%
show_image_grayscale(join_image_pieces_into_one(
    image_pieces_segmented,
    additive_method_num_rows,
    additive_method_num_cols,
    additive_method_step))

# %% [markdown]
# ### Método de Otsu
#
# El método de Otsu supone que los pixeles de la imagen $f(x,y)$ pueden ser separados a raves de un umbral $u$ en dos clases: $C_1$, la clase del objeto u objetos de interés y $C_2$, la clase de pixeles de fondo.
#
# Definamos las siguientes variables:
#
#
# $r$ es el nivel de gris de un pixel con coordenadas $f(x,y)$.
#
# $L$ es el número de niveles de gris de la imgan $f(x,y)$ con $0 \leq r \leq L-1$
#
# $p_r$ es el número de pixeles con el nivel de gris $r$.
#
# $N_T = p_0 + p_1 + \ldots + p_r + \ldots + p_{L-1}$ esl número total de pixeles
#
# $p(r) = \frac{p_r}{N_T}$ es el histograma normalizado de niveles de gris de $N_T$
#
# El método de otsu quiere maximizar la función $J_3 (r)$ de manera que
#
# $u* = \text{arg max } J_3 (r)$
#
# para los r en el rango $0 \leq r \leq L-1$

# %%
N_T = image_data.shape[0] * image_data.shape[1]
p_sub_rs = np.histogram(image_data.ravel(), bins=range(1, 256))[0]
p_of_rs = list(map(lambda x: x / N_T, p_sub_rs))

# %%
def otsu_P1(u):
    return sum(p_of_rs[0:u+1])
    
def otsu_P2(u):
    return sum(p_of_rs[u+1:-1])
    
def otsu_mu1(u):
    return (1/otsu_P1(u))*sum([r * p_of_rs[r] for r in range(0, u+1)])
    
def otsu_mu2(u):
    return (1/otsu_P2(u))*sum([r * p_of_rs[r] for r in range(u+1, -1)])
    
def otsu_mu():
    return sum([r * p_of_rs[r] for r in range(254)])
    
def otsu_sigma_squared():
    mu = otsu_mu()
    return sum([ ((r - mu)**2) * p_of_rs[r] for r in range(254) ])

def otsu_J3(u):
    return ((otsu_P1(u) * otsu_P2(u)) * (otsu_mu1(u) - otsu_mu2(u))**2) / otsu_sigma_squared()
    
def otsu_maximize():
    results = []
    for u in range(254):
        try:
            results.append(otsu_J3(u))
        except:
            results.append(0)
    maximum = -65536
    max_index = -1
    for index, val in enumerate(results):
        if val > maximum:
            maximum = val
            max_index = index
    return max_index

u_star = otsu_maximize()
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in double_scalars
#
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars

# %%
otsu_binarize = np.vectorize(partial(binarize_image, threshold=u_star))
plt.figure()
plt.title('Binarization by otsu, u* = {}'.format(u_star))
show_image_grayscale(otsu_binarize(image_data))

# %% [markdown]
# ## Etiquetado
#
# Una vez que se ha binarizado una imagen, en el caso de que haya más de un objeto en la imagen y que sus posiciones y orientación requieren ser definidios tiene que realizarse un proceso de etiquetado. Este proceso asigna a cada componente conectado CC de pixeles de una misma intensidad después de la binarización una etiqueta única (por CC).

# %%
binarized_image = mode_image_data
show_image_grayscale(binarized_image)

# %% [markdown]
# ### Método recursivo
#
# 1. Barrer b(x,y) hasta encontrar un pizel de tipo objecto (con valor 1 o L-1) aún no etiquetado y asignarle una nueva etiqueta E.
#
# 2. Asignar de forma recursiva la etiqueta E a todos su vecinos según sea la métrica elegida.
#
# 3. Detenerse si durante el recorrido no se encuentran más píxeles de tipo objeto.
#
# 4. Regresar al paso 1.

# %%
# next_label = 1

# def propagate(data, label, start_row, start_col):
#     if (data[start_row, start_col] == 255 and
#         (start_row >= 0 and start_col >= 0) and
#         (start_row <= data.shape[0] and start_col <= data.shape[1])):
#         data[start_row, start_col] = label
#         propagate(data, label, start_row - 1, start_col - 1)
#         propagate(data, label, start_row - 1, start_col)
#         propagate(data, label, start_row - 1, start_col + 1)
#         propagate(data, label, start_row, start_col - 1)
#         propagate(data, label, start_row, start_col + 1)
#         propagate(data, label, start_row + 1, start_col - 1)
#         propagate(data, label, start_row + 1, start_col)
#         propagate(data, label, start_row + 1, start_col + 1)

# def sweep(image_data):
#     image = image_data.copy()
#     shape = image_data.shape
#     rows = shape[0]
#     cols = shape[1]
    
#     cur_label = 0
    
#     for cur_row in range(rows):
#         for cur_col in range(cols):
#             if image[cur_row, cur_col] == 255: # assumes there wont be more than 254 connected components
#                 cur_label += 1
#                 propagate(image, cur_label, cur_row, cur_col)
                
#     return image, cur_label

# def recursive_labelling(image_data):
#     return sweep(image_data)
    

# recursively_labeled_image, num_labels = recursive_labelling(binarized_image)


# plt.imshow(recursively_labeled_image)

# %% [markdown]
# ### Método iterativo

# %%
def label_neighbors(data, label, row, col):
    if ((row - 1) > 0) and data[row - 1][col] != 0:
        data[row - 1][col] = label
    if ((row + 1) < data.shape[0]) and data[row + 1][col] != 0:
        data[row + 1][col] = label
    if ((col - 1) > 0) and data[row][col - 1] != 0:
        data[row][col - 1] = label
    if ((col + 1) < data.shape[1]) and data[row][col + 1] != 0:
        data[row][col + 1] = label
    if ((row - 1) > 0 and (col - 1) > 0) and data[row - 1][col - 1] != 0:
        data[row - 1][col - 1] = label
    if ((row + 1) < data.shape[0] and (col + 1) < data.shape[1]) and data[row + 1][col + 1] != 0:
        data[row + 1][col + 1] = label
    if ((row - 1) > 0 and (col + 1) < data.shape[1]) and data[row - 1][col + 1] != 0:
        data[row - 1][col + 1] = label
    if ((row + 1) < data.shape[0] and (col - 1) > 0) and data[row + 1][col - 1] != 0:
        data[row + 1][col - 1] = label

def label_iteratively(image_data):
    image = image_data.copy()
    shape = image.shape
    num_rows = shape[0]
    num_cols = shape[1]
    
    cur_label = 5
    
    for cur_row in range(num_rows):
        for cur_col in range(num_cols):
            if image[cur_row, cur_col] == 255:
                image[cur_row, cur_col] = cur_label
                cur_label += 5
            
    for cur_col in range(num_cols):
        for cur_row in range(num_rows):
            if image[cur_row, cur_col] != 0:
                label_neighbors(image, image[cur_row, cur_col], cur_row, cur_col)

    for cur_col in range(num_cols - 1, 0, -1):
        for cur_row in range(num_rows):
            if image[cur_row, cur_col] != 0:
                label_neighbors(image, image[cur_row, cur_col], cur_row, cur_col)
                
    for cur_row in range(num_rows):
        for cur_col in range(num_cols):
            if image[cur_row, cur_col] != 0:
                label_neighbors(image, image[cur_row, cur_col], cur_row, cur_col)
                
    for cur_row in range(num_rows - 1, 0, -1):
        for cur_col in range(num_cols):
            if image[cur_row, cur_col] != 0:
                label_neighbors(image, image[cur_row, cur_col], cur_row, cur_col)
                
    color = image_color.copy()
    
    for cur_row in range(num_rows):
        for cur_col in range(num_cols):
            if image[cur_row,cur_col] == 0:
                color[cur_row, cur_col, 0] = 255
                color[cur_row, cur_col, 1] = 255
                color[cur_row, cur_col, 2] = 255
            else:
                color[cur_row, cur_col, 0] = image[cur_row, cur_col] if image[cur_row, cur_col] % 2 == 0 else 0 
                color[cur_row, cur_col, 1] = image[cur_row, cur_col]
                color[cur_row, cur_col, 2] = 0
    
    return color

plt.imshow(label_iteratively(binarized_image))
